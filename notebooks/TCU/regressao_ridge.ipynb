# %% [markdown]
# ## Importação de Pacotes

# %%
#leitura da base de dados
import pandas as pd
from pathlib import Path

#modelo preditivo escolhido
from sklearn import linear_model

#validação cruzada
from sklearn.model_selection import train_test_split, GridSearchCV

#métricas
import matplotlib
from sklearn.metrics import accuracy_score, f1_score, recall_score, ConfusionMatrixDisplay

# %% [markdown]
# ## Leitura do DataFrame

# %%
direcao = Path("../..") / "data"
caminho = direcao / "df_tcu.csv"

df = pd.read_csv(caminho)

# %%
#transformando coluna númerica em float64 (no df original encontra-se como str)
df["materialidade_valor_envolvido"] = pd.to_numeric(df["materialidade_valor_envolvido"], errors= "coerce")

#invertendo os valores da coluna de admissibilidade
df["admissibilidade_concedida"] = df["admissibilidade_concedida"].replace({0: 1, 1: 0})

# %%
var_dependentes = ['admissibilidade_concedida', 'exame_sumario', 'perigo_demora', 'perigo_demora_reverso','plausibilidade_juridica', 'decisao_cautelar', 'oitiva', 'diligencia', 'oitiva_previa', 'merito']

df_dependentes = df[var_dependentes]
df_dependentes.columns
# Out:
# Index(['admissibilidade_concedida', 'exame_sumario', 'perigo_demora',
#        'perigo_demora_reverso', 'plausibilidade_juridica', 'decisao_cautelar',
#        'oitiva', 'diligencia', 'oitiva_previa', 'merito'],
#       dtype='object')

# %%
df_independentes = df.drop(columns=var_dependentes)
df_independentes.columns
# Out:
# Index(['codigo', 'numeroCompleto', 'numero_only', 'ano', 'siglaTipoProcesso',
#        'assunto', 'descricaoUnidadeResponsavelTecnica',
#        'descricaoSubUnidadeResponsavelTecnica', 'siglaRelator',
#        'dataAutuacaoFormatada', 'unidade_codigo', 'unidade_nome',
#        'unidade_siglaUF', 'unidade_cidade', 'unidade_codigoSiafi',
#        'representado_nome', 'representado_codigo', 'representante_nome',
#        'representante_codigo', 'representante_cpf', 'representante_registro',
#        'arquivo', 'estado_licitacao', 'data_instrucao',
#        'materialidade_valor_envolvido', 'id', 'irregularidade_alegada',
#        'categoria_de_proposta', 'partes_envolvidas', 'descricao_detalhada',
#        'conduta', 'fundamento_legal', 'resultado_nexo_causal', 'evidencias',
#        'particularidades_caso', 'resposta_ente_licitante',
#        'ref_processo_associado', 'ref_tipo_referencia', 'ref_camara',
#        'ref_numero_referencia', 'ref_origem_referencia',
#        'ref_conteudo_julgado', 'ref_classificacao_referencia',
#        'ref_resultado_utilizacao', 'arquivo_sem_json', 'numero_processo',
#        'apreciou_cautelar'],
#       dtype='object')

# %% [markdown]
# ## Pré-Processamento dos Dados

# %%
#Para fins deste notebook, a variável dependente escolhida é a coluna "admissibilidade_concedida"
#Objetivo é predizer em quais procedimentos no TCU foram cumpridos os pressupostos procedimentais

df_dummies = pd.get_dummies(df, columns=["categoria_de_proposta"], drop_first=True, dtype=int)

df_dummies = df_dummies.dropna(subset="materialidade_valor_envolvido")

lista_exclusao = [
    'codigo', 'numeroCompleto', 'numero_only', 'ano', 'siglaTipoProcesso',
    'assunto', 'descricaoUnidadeResponsavelTecnica',
    'descricaoSubUnidadeResponsavelTecnica', 'siglaRelator',
    'dataAutuacaoFormatada', 'unidade_codigo', 'unidade_nome',
    'unidade_siglaUF', 'unidade_cidade', 'unidade_codigoSiafi',
    'representado_nome', 'representado_codigo', 'representante_nome',
    'representante_codigo', 'representante_cpf', 'representante_registro',
    'arquivo', 'estado_licitacao', 'data_instrucao', 'id', 'irregularidade_alegada',
    'partes_envolvidas', 'descricao_detalhada', 'conduta', 'fundamento_legal',
    'resultado_nexo_causal', 'evidencias', 'particularidades_caso',
    'resposta_ente_licitante', 'ref_processo_associado', 'ref_tipo_referencia',
    'ref_camara', 'ref_numero_referencia', 'ref_origem_referencia',
    'ref_conteudo_julgado', 'ref_classificacao_referencia',
    'ref_resultado_utilizacao', 'arquivo_sem_json', 'numero_processo',
    'apreciou_cautelar', 'admissibilidade_concedida', 'exame_sumario', 'perigo_demora',
    'perigo_demora_reverso', 'plausibilidade_juridica', 'decisao_cautelar',
    'oitiva', 'diligencia', 'oitiva_previa', 'merito'
]

# %%
X = df_dummies.drop(columns=lista_exclusao, axis=1) #variáveis independentes são "materialidade_valor_envolvido" e ""categoria_de_proposta"
y = df_dummies["admissibilidade_concedida"]

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=22)

# %% [markdown]
# ## Ajuste do Modelo

# %%
ridge = linear_model.RidgeClassifier()

ridge.fit(X_train, y_train)

ridge
# Out:
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.45337e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# RidgeClassifier()

# %% [markdown]
# ### **Métricas**

# %%
ConfusionMatrixDisplay.from_estimator(ridge, X_test, y_test)

# %%
y_pred = ridge.predict(X_test)

acuracia = accuracy_score(y_test, y_pred)
F1 = f1_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print(f"""
      Acurária: {round(acuracia,3)};
      F1: {round(F1,3)};
      Revocação: {round(recall,3)}
      """)
# Out:
#       Acurária: 0.839;
#       F1: 0.0;
#       Revocação: 0.0

# %% [markdown]
# ## Aplicando Validação Cruzada

# %%
parametros = {"alpha": [0.01, 0.1, 1, 10, 100]}

grid = GridSearchCV(ridge, parametros, scoring="roc_auc", cv=5)

grid.fit(X_train, y_train)

ridge_CV = grid.best_estimator_

ridge_CV.fit(X_train, y_train)
# Out:
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.85992e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.67067e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.82398e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.85052e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.65442e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.86931e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.685e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.83783e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.85894e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.663e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.9633e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.82836e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.97634e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.94325e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.74889e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.9078e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.26935e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.36853e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.7907e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.61221e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.36457e-19): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.11412e-19): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.07404e-19): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.2545e-19): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.25247e-19): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.37069e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.37069e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# RidgeClassifier(alpha=0.1)

# %% [markdown]
# ### **Métricas**

# %%
ConfusionMatrixDisplay.from_estimator(ridge_CV, X_test, y_test)

# %%
y_pred = ridge_CV.predict(X_test)

acuracia = accuracy_score(y_test, y_pred)
F1 = f1_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print(f"""
      Acurária_CV: {round(acuracia,3)};
      F1_CV: {round(F1,3)};
      Revocação_CV: {round(recall,3)}""")
# Out:
#       Acurária_CV: 0.839;
#       F1_CV: 0.0;
#       Revocação_CV: 0.0
