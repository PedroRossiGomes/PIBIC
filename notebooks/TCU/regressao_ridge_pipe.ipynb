# %% [markdown]
# # Importação de Pacotes

# %%
#leitura da base de dados
import pandas as pd
from pathlib import Path

#modelo preditivo escolhido
from sklearn import linear_model

#validação cruzada
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, HalvingGridSearchCV
import numpy as np

#métricas
import matplotlib
from sklearn.metrics import accuracy_score, f1_score, recall_score, roc_auc_score, ConfusionMatrixDisplay

#pipelines
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from sklearn.compose import ColumnTransformer, TransformedTargetRegressor
from sklearn.impute import SimpleImputer

# %%
def estimadores(modelo, X_test, y_test):
    y_pred = modelo.predict(X_test)
    
    acuracia = accuracy_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred)

    print(
        ConfusionMatrixDisplay.from_estimator(modelo, X_test, y_test)
    )

    print(f"""
      Acurária: {round(acuracia,3)};
      Revocação: {round(recall,3)};
      F1: {round(F1,3)};
      Roc_Auc: {round(roc_auc,3)}""")

# %% [markdown]
# ## Leitura DataFrame

# %%
direcao = Path("../..") / "data"
caminho = direcao / "df_tcu.csv"

df = pd.read_csv(caminho)

# %% [markdown]
# ### Escolha do Modelo

# %%
modelo= linear_model.RidgeClassifier()

# %% [markdown]
# ### Escolha dos HiperParâmetros

# %%
parametros = {
    "modelo__alpha": [0.01, 0.1, 1, 10, 100]
    }

# %% [markdown]
# # Aplicação de Pipelines

# %%
X = df[["materialidade_valor_envolvido", "categoria_de_proposta"]]
y = df["admissibilidade_concedida"].replace({0: 1, 1: 0})

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=22)


#transformando coluna númerica em float64 (no df original encontra-se como str)
def numerico(coluna):
    return(pd.to_numeric(coluna.squeeze(), errors="coerce").to_frame())

#preparando a coluna "materialidade_valor_envolvido"
num_prep = Pipeline(steps=[
    ('tranformer_num', FunctionTransformer(numerico)),
    ('imputer', SimpleImputer(strategy='median'))
])

#pipeline de dummies
cat_prep = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))])


preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_prep, ["materialidade_valor_envolvido"]),
        ('cat', cat_prep, ["categoria_de_proposta"])
    ])

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('modelo', modelo)
    ])

searchCV_pipeline = RandomizedSearchCV(
    pipeline,
    parametros,
    scoring='roc_auc',
    refit='roc_auc',
    cv=5
)

searchCV_pipeline.fit(X_train, y_train)
# Out:
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 5 is smaller than n_iter=10. Running 5 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.65516e-23): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.30466e-23): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.84357e-23): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.77784e-23): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.79567e-23): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.65516e-22): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.30466e-22): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.84357e-22): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.77784e-22): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.79567e-22): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.65516e-21): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.30466e-21): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.84357e-21): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.77784e-21): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.79567e-21): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.65516e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.30466e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.84357e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.77784e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.79567e-20): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.65516e-19): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.30466e-19): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.84357e-19): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.77784e-19): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.79567e-19): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\peper\OneDrive\Documentos\PIBIC\.venv\Lib\site-packages\scipy\_lib\_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.48138e-19): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('num',
#                                                                                Pipeline(steps=[('tranformer_num',
#                                                                                                 FunctionTransformer(func=<function numerico at 0x0000024312EEADE0>)),
#                                                                                                ('imputer',
#                                                                                                 SimpleImputer(strategy='median'))]),
#                                                                                ['materialidade_valor_envolvido']),
#                                                                               ('cat',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('onehot',
#                                                                                                 OneHotEncoder(handle_unknown='ignore',
#                                                                                                               sparse_output=False))]),
#                                                                                ['categoria_de_proposta'])])),
#                                              ('modelo', RidgeClassifier())]),
#                    param_distributions={'modelo__alpha': [0.01, 0.1, 1, 10,
#                                                           100]},
#                    refit='roc_auc', scoring='roc_auc')

# %%
estimadores(searchCV_pipeline, X_test, y_test)
# Out:
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000024310D0B620>
#
#       Acurária: 0.848;
#       Revocação: 0.0;
#       F1: 0.0;
#       Roc_Auc: 0.499
